# %%
import pandas as pd
import mysql.connector

conn = mysql.connector.connect(
        ###
        )

cur = conn.cursor()

cur.execute("""
SELECT * FROM scrapy_crawl_results
""")

data = cur.fetchall()

# %%
columns = ['date', 'business_name', 'owners', 'owner_name', 'commercial_registered_agent', 'registered_agent']
df = pd.DataFrame(data, columns=columns)
df
# Out:
#           date                        business_name owners  \
# 0   2023-01-20                              XH, LLC   NULL
# 1   2023-01-20        XERCOR INSURANCE SERVICES LLC   NULL
# 2   2023-01-20                          XENITH, LLC   NULL
# 3   2023-01-20     Xenex Disinfection Services Inc.   NULL
# 4   2023-01-20        Xencom Energy Management, LLC   NULL
# 5   2023-01-20             Xelix Distribution, Inc.   NULL
# 6   2023-01-20                           XeCare LLC   NULL
# 7   2023-01-20                            XEBU, LLC   NULL
# 8   2023-01-20         XEROX FINANCIAL SERVICES LLC   NULL
# 9   2023-01-20                         XZILON, INC.   NULL
# 10  2023-01-20       Xcel Automation & Electric LLC   NULL
# 11  2023-01-20                        XAPIC STUDIOS   NULL
# 12  2023-01-20                    XCEL AGRONOMY LLC   NULL
# 13  2023-01-20        Xander Products & Service LLC   NULL
# 14  2023-01-20          XCED AVIATION SERVICES, LLC   NULL
# 15  2023-01-20  XCALIBER INTERNATIONAL LTD., L.L.C.   NULL
# 16  2023-01-20              XANADU PRODUCTS, L.L.C.   NULL
# 17  2023-01-20                      XAP Corporation   NULL
# 18  2023-01-20                          Xactus, LLC   NULL
# 19  2023-01-20                 XactlyOne Foundation   NULL
# 20  2023-01-20                    Xcel Holdings LLC   NULL
# 21  2023-01-20       Xcel Automation & Electric LLC   NULL
# 22  2023-01-20                      Xcel Automation   NULL
# 23  2023-01-20                    XCEL AGRONOMY LLC   NULL
# 24  2023-01-20                        Xcel Holdings   NULL
# 25  2023-01-20          XCED AVIATION SERVICES, LLC   NULL
# 26  2023-01-20                XCEL AG SOLUTIONS LLC   NULL
# 27  2023-01-20                        Xcel Aviation   NULL
# 28  2023-01-20                     XCAST LABS, INC.   NULL
# 29  2023-01-20                          XCEL ENERGY   NULL
#
#                         owner_name               commercial_registered_agent  \
# 0                             NULL               CORPORATION SERVICE COMPANY
# 1                             NULL                       COGENCY GLOBAL INC.
# 2                             NULL                   UNITED AGENT GROUP INC.
# 3                             NULL                     INCORP SERVICES, INC.
# 4                             NULL          REGISTERED AGENT SOLUTIONS, INC.
# 5                             NULL                    C T CORPORATION SYSTEM
# 6                             NULL          CAPITOL CORPORATE SERVICES, INC.
# 7                             NULL                                      NULL
# 8                             NULL               CORPORATION SERVICE COMPANY
# 9                             NULL               CORPORATION SERVICE COMPANY
# 10                            NULL                                      NULL
# 11              PATRICIA A ROGALLA                                      NULL
# 12                            NULL                                      NULL
# 13                            NULL                                      NULL
# 14                            NULL                    C T CORPORATION SYSTEM
# 15                            NULL               CORPORATION SERVICE COMPANY
# 16                            NULL                                      NULL
# 17                            NULL               CORPORATION SERVICE COMPANY
# 18                            NULL               CORPORATION SERVICE COMPANY
# 19                            NULL  NORTHWEST REGISTERED AGENT SERVICE, INC.
# 20                            NULL                                      NULL
# 21                            NULL                                      NULL
# 22  Xcel Automation & Electric LLC                                      NULL
# 23                            NULL                                      NULL
# 24                 Tanner Collette                                      NULL
# 25                            NULL                    C T CORPORATION SYSTEM
# 26                            NULL                                      NULL
# 27               Tanner S Collette                                      NULL
# 28                            NULL                     INCORP SERVICES, INC.
# 29   NORTHERN STATES POWER COMPANY                                      NULL
#
#                   registered_agent
# 0                             NULL
# 1                             NULL
# 2                             NULL
# 3                             NULL
# 4                             NULL
# 5                             NULL
# 6                             NULL
# 7   CORPORATE SERVICE CENTER, INC.
# 8                             NULL
# 9                             NULL
# 10                TANNER  COLLETTE
# 11                            NULL
# 12          CHRISTOPHER  PERLEBERG
# 13              ALEXANDER G. MUGAN
# 14                            NULL
# 15                            NULL
# 16                   RICK  PAULSON
# 17                            NULL
# 18                            NULL
# 19                            NULL
# 20                TANNER  COLLETTE
# 21                TANNER  COLLETTE
# 22                            NULL
# 23          CHRISTOPHER  PERLEBERG
# 24                            NULL
# 25                            NULL
# 26            ANTHONY  BAUMGARTNER
# 27                            NULL
# 28                            NULL
# 29                            NULL
