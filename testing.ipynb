# %%
import pandas as pd
import mysql.connector

conn = mysql.connector.connect(
        ###
        )

cur = conn.cursor()

cur.execute("""
SELECT * FROM scrapy_crawl_results
""")

data = cur.fetchall()

# %%
columns = ['scrape_date', 'business_name', 'owners', 'owner_name', 'commercial_registered_agent', 'registered_agent']
df = pd.DataFrame(data, columns=columns)
df
# Out:
#     scrape_date                       business_name owners  \
# 0    2023-01-21                   XEROX CORPORATION   NULL
# 1    2023-01-21                          XeCare LLC   NULL
# 2    2023-01-21               Xebec Systems USA LLC   NULL
# 3    2023-01-21                              Xe USA   NULL
# 4    2023-01-21                     XDP Digital LLC   NULL
# ..          ...                                 ...    ...
# 174  2023-01-21                        X Golf Minot   NULL
# 175  2023-01-21  X S BROKERS INSURANCE AGENCY, INC.   NULL
# 176  2023-01-21                XactlyOne Foundation   NULL
# 177  2023-01-21                    XCEL ENERGY INC.   NULL
# 178  2023-01-21                     X Golf Bismarck   NULL
#
#                                owner_name  \
# 0                                    NULL
# 1                                    NULL
# 2                                    NULL
# 3    CONTINENTAL EXCHANGE SOLUTIONS, INC.
# ...
